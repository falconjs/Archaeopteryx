# %%
# %run pandas_DataFrame_plot.py
# Out:
#                    A         B         C         D  X  Y  Z
# 2020-02-01 -1.738791 -0.526239  0.352924 -0.994147  1  3  3
# 2020-02-02 -0.296900 -1.140517 -0.650595  1.353451  3  1  0
# 2020-02-03  0.479987  0.541000 -0.083412  0.234536  4  3  1
# 2020-02-04 -0.771383  0.147394 -0.619141 -1.501180  0  0  4
# 2020-02-05  0.152475 -0.447507 -0.595698 -0.354580  3  2  2
# [0, 1, 2, 3, 4]

# %%
# %load_ext autoreload

# %%
# %autoreload 1
# %aimport pandas_DataFrame_plot

# %%
pandas_DataFrame_plot.df_plot_3(pandas_DataFrame_plot.df4)
# Out:
#                    A         B         C         D  X  Y  Z
# 2020-02-01 -0.007839 -0.741595  0.128273 -0.780318  3  1  4
# 2020-02-02  0.476022  0.355824  0.931664 -0.071774  4  1  2
# 2020-02-03 -1.109201 -0.900971 -1.405035  0.027716  4  1  0
# 2020-02-04 -0.175735 -0.599313 -1.216019 -1.231659  3  4  3
# 2020-02-05 -0.471863  0.177435  0.897208  1.263942  1  4  3
# [0, 1, 2, 3, 4]
