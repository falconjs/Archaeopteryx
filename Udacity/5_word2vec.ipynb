# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'
data_root = '../../input/data_compression/' # Change me to store data elsewhere

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    dest_filename = os.path.join(data_root, filename)
    if not os.path.exists(dest_filename):
        filename, _ = urlretrieve(url + filename, dest_filename)
    statinfo = os.stat(dest_filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % dest_filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + dest_filename + '. Can you get to it with a browser?')
    return dest_filename


filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified ../../input/data_compression/text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data


words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    # count = Counter({'abc': 3, 'cde': 2, 'bcd': 1, 'def': 1})
    
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    # dictionary = ('abc': 1, 'cde': 2, 'bcd': 3, 'def': 4)    
    
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary


data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0


def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window

    # print("batch_size =", batch_size)
    # print("num_skips =", num_skips)
    # print("skip_window =", skip_window)

    batch = np.ndarray(shape=(batch_size), dtype=np.int32)  # batch.shape = [8]
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32) # labels.shape = [8, 1]
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]

    # print("span =", span)

    # use deque to append the new word at the tail , push the old word out from top
    buffer = collections.deque(maxlen=span)

    for _ in range(span):
        # pick the word's rank/index into buffer [3]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    # print("buffer =", buffer)
    # print("data_index =", data_index)

    # Buffer : deque([5234, 3081, 12])

    for i in range(batch_size // num_skips): # 4
        target = skip_window  # target label at the center of the buffer , 1 of [0..2]
        targets_to_avoid = [skip_window]   # [1]
        for j in range(num_skips): # (0...1)

            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
                # random number from (0, 1, 2) until find a number not in targets_to_avoid
                # to get the new neighbour words

            targets_to_avoid.append(target)
            # print("i:", i, "j:", j, "targets_to_avoid:",targets_to_avoid, "buffer =", buffer)

            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target] # neighbour of the words
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    # print("batch =", batch)
    # print("labels =", labels)
    # print("buffer =", buffer)
    # print("data_index =", data_index)

    return batch, labels

# %%
print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'anarchism', 'term', 'originated', 'of', 'as', 'term', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64  # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                                                      stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                                   labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    valid_norm_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)

    # Calculate cosine distance from valid words to all the other words.
    # cosine distance represent the similarity between 2 words.
    similarity = tf.matmul(valid_norm_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset: batch_data, train_labels: batch_labels}

        _, l = session.run([optimizer, loss], feed_dict=feed_dict)

        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0

        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):

                valid_word = reverse_dictionary[valid_examples[i]]

                top_k = 8  # number of nearest neighbors
                # ignore 0 , 0 refer to itself
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
                
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.417866
# Nearest to up: derisively, traction, alberoni, spans, matched, anatolian, troppo, potsdam,
# Nearest to of: beauties, pizarro, unidentified, warms, crackers, derleth, sequencer, administer,
# Nearest to s: moths, toppling, nokia, employs, subhas, pork, faure, breached,
# Nearest to history: claimant, amethyst, heeled, those, yuga, hitchens, dddddd, dominated,
# Nearest to and: fortnight, tractor, ata, bnf, audrey, skip, flagship, mpla,
# Nearest to from: neighbours, concentrate, sensory, riga, pitching, malware, surprised, legalism,
# Nearest to by: rulings, computation, obstetrics, veneer, rites, magazines, disraeli, linton,
# Nearest to however: checklist, coro, repairs, nippon, uninterrupted, reversible, politecnico, dd,
# Nearest to a: prasad, tidy, tines, realign, trainees, netscape, vilnius, currency,
# Nearest to there: descriptive, lipoprotein, navigated, deadliest, crusader, alberti, simons, erroneously,
# Nearest to between: zombie, dismantled, coffey, unsympathetic, tenor, tenth, ramones, pataki,
# Nearest to only: toxic, martinique, shadow, cno, cyanobacteria, rico, endeavour, affect,
# Nearest to th: bipedal, chaste, particularity, lmi, origin, gravesite, ignition, brochure,
# Nearest to one: disseminated, coincided, circ, discs, carving, monophysitism, molino, cockney,
# Nearest to as: microcebus, biomes, capitalize, vicarious, aqdas, host, chu, malinowski,
# Nearest to on: oceans, moksha, deep, codes, unbaptized, spokane, hazmi, observable,
# Average loss at step 2000: 4.504091
# Average loss at step 4000: 4.122377
# Average loss at step 6000: 3.918333
# Average loss at step 8000: 3.925692
# Average loss at step 10000: 3.887101
# Nearest to up: according, derisively, edif, neurologist, troppo, traction, hep, alberoni,
# Nearest to of: in, with, from, moyen, and, fetal, for, cosmic,
# Nearest to s: his, UNK, in, five, the, blotting, leda, and,
# Nearest to history: heeled, dddddd, antlia, those, beards, commanding, deceiver, nome,
# Nearest to and: with, in, UNK, on, from, by, of, to,
# Nearest to from: in, of, and, with, malt, riga, sensory, by,
# Nearest to by: in, with, and, ethnologue, rapper, from, slip, vietnamese,
# Nearest to however: checklist, gypsys, curtius, rediscovered, determined, uninterrupted, against, gwadar,
# Nearest to a: the, an, logarithmic, debatable, brings, unimpeded, this, tess,
# Nearest to there: erroneously, crusader, descriptive, myron, it, lipoprotein, regarding, alberti,
# Nearest to between: zombie, portfolio, curls, tenth, penang, dismantled, princesses, capitan,
# Nearest to only: tianjin, martinique, rico, affect, cyanobacteria, toxic, shadow, endeavour,
# Nearest to th: seven, five, eight, bipedal, chaste, satisfying, six, amuse,
# Nearest to one: seven, two, five, four, nine, eight, six, three,
# Nearest to as: is, sung, in, berlitz, tossing, marketshare, cultural, molloy,
# Nearest to on: in, and, with, libri, from, by, anastasio, for,
# Average loss at step 12000: 3.869633
# Average loss at step 14000: 3.838483
# Average loss at step 16000: 3.740054
# Average loss at step 18000: 3.809575
# Average loss at step 20000: 3.802054
# Nearest to up: according, forward, derisively, eurasian, march, troppo, neurologist, missionaries,
# Nearest to of: and, s, mouthwash, in, under, ipo, from, sco,
# Nearest to s: his, of, and, heavenly, costing, cellar, pedagogic, categorically,
# Nearest to history: dddddd, beards, antlia, deceiver, rounding, perigee, commanding, heeled,
# Nearest to and: of, or, in, by, UNK, conscripted, s, interoperable,
# Nearest to from: in, below, by, friars, capitan, sensory, into, with,
# Nearest to by: and, who, from, ethnologue, sphincter, which, authentically, toasts,
# Nearest to however: gypsys, checklist, bills, rediscovered, that, dd, bundesland, gwadar,
# Nearest to a: the, an, any, derided, logarithmic, online, aloe, kane,
# Nearest to there: it, they, crusader, liquidity, descriptive, these, ferroelectric, alkene,
# Nearest to between: capitan, curls, portfolio, rotors, penang, treblinka, with, coffey,
# Nearest to only: cyanobacteria, theology, affect, sequencer, relations, shadow, pies, jabberwocky,
# Nearest to th: five, eight, six, bipedal, chaste, four, zero, amuse,
# Nearest to one: eight, three, nine, six, seven, five, two, zero,
# Nearest to as: backpacker, slime, serviced, daugavpils, bandar, masks, admitted, bbses,
# Nearest to on: in, libri, at, enveloping, from, hern, javier, kbit,
# Average loss at step 22000: 3.735199
# Average loss at step 24000: 3.778785
# Average loss at step 26000: 3.629601
# Average loss at step 28000: 3.592343
# Average loss at step 30000: 3.637988
# Nearest to up: forward, troppo, derisively, into, according, massoud, tricolor, eurasian,
# Nearest to of: s, from, and, moyen, during, lada, barrier, mouthwash,
# Nearest to s: his, of, germanicus, heavenly, pedagogic, visionary, solitaire, siddhartha,
# Nearest to history: rounding, oracles, anne, antlia, psalms, saga, deceiver, beards,
# Nearest to and: from, or, of, but, with, in, airbase, by,
# Nearest to from: into, and, to, by, of, friars, reclining, in,
# Nearest to by: vietnamese, from, which, who, he, and, when, ethnologue,
# Nearest to however: gypsys, but, gwadar, while, that, checklist, since, longbowmen,
# Nearest to a: the, an, his, carbonate, steady, kane, this, dismay,
# Nearest to there: it, they, liquidity, exercised, these, regarding, doth, crusader,
# Nearest to between: with, curls, capitan, iole, portfolio, rotors, petroleum, regarding,
# Nearest to only: theology, cyanobacteria, effeminate, eden, purview, succinctly, paranoia, affect,
# Nearest to th: zero, four, bipedal, chaste, eight, cm, deaths, about,
# Nearest to one: nine, seven, eight, five, six, three, two, zero,
# Nearest to as: known, slime, wheaton, admitted, pad, ipswich, recovery, masks,
# Nearest to on: libri, bin, in, from, indochina, of, thoroughfares, enveloping,
# Average loss at step 32000: 3.669815
# Average loss at step 34000: 3.751643
# Average loss at step 36000: 3.682080
# Average loss at step 38000: 3.726204
# Average loss at step 40000: 3.676255
# Nearest to up: forward, them, according, troppo, him, tricolor, derisively, boilers,
# Nearest to of: for, in, moyen, philia, within, from, nucleosynthesis, hydroxyproline,
# Nearest to s: bodhidharma, solitaire, his, lloyd, maitland, toes, mjw, stare,
# Nearest to history: fictional, rounding, list, saga, xn, acupuncture, anne, beards,
# Nearest to and: or, but, with, for, buddhas, from, evolutionarily, ipv,
# Nearest to from: in, through, brythonic, by, confirm, mons, and, into,
# Nearest to by: ethnologue, from, that, have, sidearm, who, vietnamese, and,
# Nearest to however: but, although, that, if, no, gypsys, while, since,
# Nearest to a: the, any, this, another, no, carbonate, tess, champ,
# Nearest to there: it, they, exercised, he, alkene, bicycles, ferroelectric, however,
# Nearest to between: curls, petroleum, portfolio, vertigo, up, capitan, cheered, tritium,
# Nearest to only: bearable, it, gai, purview, helped, succinctly, soe, paranoia,
# Nearest to th: nd, rd, deaths, nine, cm, bytes, citt, chaste,
# Nearest to one: seven, six, eight, two, five, nine, four, three,
# Nearest to as: known, restaurant, evolutionary, tossing, flash, such, thoroughfares, slime,
# Nearest to on: upon, lugo, external, metaphor, orthodox, but, javier, enveloping,
# Average loss at step 42000: 3.677143
# Average loss at step 44000: 3.706284
# Average loss at step 46000: 3.673089
# Average loss at step 48000: 3.748870
# Average loss at step 50000: 3.646304
# Nearest to up: forward, tricolor, troppo, into, him, march, eleven, according,
# Nearest to of: in, s, after, and, under, before, for, during,
# Nearest to s: his, of, UNK, her, adorno, and, the, overall,
# Nearest to history: list, amateurs, anne, psalms, supporter, chan, wales, usa,
# Nearest to and: but, or, of, s, brewers, in, when, which,
# Nearest to from: into, through, at, before, by, sensory, for, taya,
# Nearest to by: who, under, ethnologue, when, from, to, had, for,
# Nearest to however: but, although, while, since, that, when, if, no,
# Nearest to a: the, any, another, counterattacks, an, cafeteria, io, dismay,
# Nearest to there: they, it, he, these, not, exercised, unaffected, ferroelectric,
# Nearest to between: with, against, curls, commended, in, through, dixon, into,
# Nearest to only: not, however, otters, soe, affect, gai, likely, destroyed,
# Nearest to th: nd, six, eight, rd, seven, deaths, st, three,
# Nearest to one: eight, nine, seven, four, two, five, six, three,
# Nearest to as: slovenes, denarius, known, microcebus, well, such, defined, honeybees,
# Nearest to on: in, illiteracy, upon, giantess, from, libri, lugo, kbit,
# Average loss at step 52000: 3.666968
# Average loss at step 54000: 3.757074
# Average loss at step 56000: 3.739483
# Average loss at step 58000: 3.660032
# Average loss at step 60000: 3.724457
# Nearest to up: them, tricolor, forward, eurasian, troppo, march, according, between,
# Nearest to of: in, contains, within, understandably, for, larps, patrol, during,
# Nearest to s: his, fiorentina, emil, waterloo, nokia, admissions, exothermic, deconstructionist,
# Nearest to history: list, psalms, xn, majority, upheavals, usa, albania, greece,
# Nearest to and: or, through, but, while, with, from, in, to,
# Nearest to from: into, through, and, at, before, in, between, rwanda,
# Nearest to by: ethnologue, drones, toasts, sidearm, discomfort, who, under, advising,
# Nearest to however: but, although, while, that, not, though, only, since,
# Nearest to a: the, another, this, any, counterattacks, hornblower, logarithmic, an,
# Nearest to there: they, it, he, colourful, longer, not, found, unaffected,
# Nearest to between: with, vertigo, in, from, up, commended, molestation, against,
# Nearest to only: however, that, she, soe, but, he, destroyed, who,
# Nearest to th: six, nd, nine, eight, three, five, rd, st,
# Nearest to one: two, nine, eight, seven, four, six, three, zero,
# Nearest to as: imp, outlook, aqdas, known, such, slovenes, aground, selling,
# Nearest to on: upon, and, from, illiteracy, through, lame, britannia, snp,
# Average loss at step 62000: 3.699609
# Average loss at step 64000: 3.709471
# Average loss at step 66000: 3.531585
# Average loss at step 68000: 3.495411
# Average loss at step 70000: 3.683131
# Nearest to up: out, him, yeti, forward, them, way, down, eurasian,
# Nearest to of: in, for, understandably, including, faqs, untouchables, like, dogmatically,
# Nearest to s: his, lathe, and, astrodome, kontor, maitland, tudes, chores,
# Nearest to history: list, see, psalms, hosted, tumours, geography, anne, england,
# Nearest to and: but, while, or, which, when, with, however, including,
# Nearest to from: into, through, effortless, on, bootable, confirm, taya, riga,
# Nearest to by: who, in, lasi, UNK, ethnologue, gl, anthology, which,
# Nearest to however: but, although, while, because, though, endowments, not, and,
# Nearest to a: the, another, an, any, this, his, caldwell, tyrone,
# Nearest to there: they, it, outbreaks, not, longer, conserve, now, sud,
# Nearest to between: with, molestation, into, nieuwe, vertigo, authorship, portfolio, tritium,
# Nearest to only: but, discredited, however, pacing, it, always, not, otters,
# Nearest to th: nd, eight, st, seven, rd, nine, four, six,
# Nearest to one: two, nine, six, eight, seven, three, four, zero,
# Nearest to as: defined, prohibited, such, outlook, is, desperate, UNK, calvin,
# Nearest to on: upon, in, lame, from, like, and, distillation, refinement,
# Average loss at step 72000: 3.602748
# Average loss at step 74000: 3.698920
# Average loss at step 76000: 3.612304
# Average loss at step 78000: 3.725532
# Average loss at step 80000: 3.649208
# Nearest to up: out, him, down, tricolor, them, way, me, fuck,
# Nearest to of: for, deafness, like, including, recognises, include, fortresses, octavio,
# Nearest to s: his, its, emil, lecturer, valentinian, soaked, their, fiorentina,
# Nearest to history: list, works, psalms, xn, baseball, deals, work, culture,
# Nearest to and: or, while, including, who, with, like, for, amundsen,
# Nearest to from: through, into, bromley, under, sensory, across, chipset, texaco,
# Nearest to by: who, angered, surveys, intensively, arrives, toasts, gl, sor,
# Nearest to however: although, but, though, because, where, while, only, until,
# Nearest to a: any, another, an, the, no, his, this, kane,
# Nearest to there: they, it, outbreaks, longer, still, rabbits, she, alkene,
# Nearest to between: with, in, into, nieuwe, molestation, against, granting, lam,
# Nearest to only: however, even, every, realizes, still, not, now, discredited,
# Nearest to th: nd, eight, nine, st, rd, zero, four, seven,
# Nearest to one: eight, three, two, nine, six, seven, four, five,
# Nearest to as: well, quintessential, aqdas, imp, prohibited, selling, lard, such,
# Nearest to on: upon, in, howling, russa, snp, plating, utilises, synonymously,
# Average loss at step 82000: 3.699971
# Average loss at step 84000: 3.639535
# Average loss at step 86000: 3.634716
# Average loss at step 88000: 3.576264
# Average loss at step 90000: 3.588748
# Nearest to up: out, them, down, tricolor, off, fuck, conical, into,
# Nearest to of: including, for, after, asphyxiation, and, under, with, within,
# Nearest to s: his, its, fairies, maitland, and, UNK, nokia, stunned,
# Nearest to history: list, ulaanbaatar, eliezer, psalms, work, foundation, quantify, baseball,
# Nearest to and: or, by, including, but, in, bridal, slashes, from,
# Nearest to from: into, through, in, dole, before, under, and, since,
# Nearest to by: and, in, was, who, lasi, under, phlogiston, vietnamese,
# Nearest to however: although, but, though, because, that, while, where, when,
# Nearest to a: the, kane, an, another, any, this, faroese, interfacing,
# Nearest to there: they, it, she, he, longer, conserve, rabbits, alkene,
# Nearest to between: with, molestation, within, against, through, granting, nieuwe, into,
# Nearest to only: still, not, outgoing, now, it, stile, impede, first,
# Nearest to th: nd, six, zero, nine, st, bce, bc, rd,
# Nearest to one: two, nine, three, six, four, eight, five, seven,
# Nearest to as: well, aqdas, palo, brennan, superscalar, known, slime, microcebus,
# Nearest to on: upon, in, unravel, from, and, through, howling, of,
# Average loss at step 92000: 3.655209
# Average loss at step 94000: 3.686635
# Average loss at step 96000: 3.636448
# Average loss at step 98000: 3.705537
# Average loss at step 100000: 3.664819
# Nearest to up: out, down, tricolor, them, yeti, me, mounted, off,
# Nearest to of: including, following, for, in, during, ticker, hydroponic, mouthwash,
# Nearest to s: his, fiorentina, hwi, randle, indymedia, saban, minnesota, disagreeable,
# Nearest to history: list, greece, supporter, alicante, iran, china, art, eliezer,
# Nearest to and: or, including, with, iud, but, while, rentals, famagusta,
# Nearest to from: into, through, across, cages, dole, according, including, under,
# Nearest to by: audiogalaxy, ethnologue, drones, toasts, strewn, alleviate, krs, midshipman,
# Nearest to however: although, but, though, while, since, that, where, when,
# Nearest to a: another, the, any, derided, interfacing, carbonate, no, hornblower,
# Nearest to there: they, it, longer, she, he, still, alkene, but,
# Nearest to between: with, through, in, molestation, against, latvia, within, portfolio,
# Nearest to only: still, outgoing, interfacing, realizes, currently, but, it, kindergarten,
# Nearest to th: nine, nd, six, eight, seven, four, zero, five,
# Nearest to one: nine, four, six, eight, seven, two, five, three,
# Nearest to as: well, aqdas, imp, denarius, trousers, crank, became, trustedbsd,
# Nearest to on: upon, through, at, libri, in, howling, indochina, until,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15, 15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i, :]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()


words = [reverse_dictionary[i] for i in range(1, num_points + 1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
